# %%
#Personal Details and age calculations

# %%
name="Asim Anan"
age=20
city="Vypin"

print("My name is",name)
print("I am " +str(age)+ " years old")
print("I live in",city)
# Out:
# My name is Asim Anan
# I am 20 years old
# I live in Vypin

# %%
months = age * 12
days = age * 365
hours = days * 24

print("Age in months:", months)
print("Age in days:", days)
print("Age in hours:", hours)
# Out:
# Age in months: 240
# Age in days: 7300
# Age in hours: 175200

# %%
age=20
print("I am " +age+ "years old") #This code has a TypeError because we can only concatenate string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 age=20
# ----> 2 print("I am " +age+ "years old") #This code has a TypeError because we can only concatenate string
#
# TypeError: can only concatenate str (not "int") to str
